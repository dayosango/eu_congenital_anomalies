# %% [markdown]
# ## EU Commission dataset on congenital anomalies

# %% [markdown]
# Analysing real-world data sourced from the EU registries of congenital anomalies.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
df = pd.DataFrame(pd.read_excel("/Users/dayosangowawa/Downloads/dataset.xlsx"))

# %%
df.head()
# Out:
#   Number of cases, prevalence per 10,000 births and proportion of the following anomalies: All Anomalies, Nervous system, Neural Tube Defects, Anencephalus and similar, Encephalocele, Spina Bifida, Hydrocephalus, Severe microcephaly, Arhinencephaly/holoprosencephaly, Eye, Anophthalmos/micropthalmos, Anophthalmos, Congenital cataract, Congenital glaucoma, Ear, face and neck, Anotia, Congenital heart defects, Common arterial truncus, Transposition of great vessels, Single ventricle, Ventricular septal defect (VSD), Atrial septal defect (ASD), Atrioventricular septal defect (AVSD), Tetralogy of Fallot, Tricuspid atresia and stenosis, Ebstein's anomaly, Pulmonary valve stenosis, Pulmonary valve atresia, Aortic valve atresia/stenosis, Hypoplastic left heart, Hypoplastic right heart, Coarctation of aorta, Total anomalous pulm venous return, Respiratory, Choanal atresia, Cystic adenomatous malf of lung, Digestive system, Oesophageal atresia with or without tracheo-oesophageal fistula, Duode
# ...

# %%
df.shape
# Out:
# (57270, 15)

# %%
df = df.iloc[1:]

# %%
df.head()
# Out:
#   Number of cases, prevalence per 10,000 births and proportion of the following anomalies: All Anomalies, Nervous system, Neural Tube Defects, Anencephalus and similar, Encephalocele, Spina Bifida, Hydrocephalus, Severe microcephaly, Arhinencephaly/holoprosencephaly, Eye, Anophthalmos/micropthalmos, Anophthalmos, Congenital cataract, Congenital glaucoma, Ear, face and neck, Anotia, Congenital heart defects, Common arterial truncus, Transposition of great vessels, Single ventricle, Ventricular septal defect (VSD), Atrial septal defect (ASD), Atrioventricular septal defect (AVSD), Tetralogy of Fallot, Tricuspid atresia and stenosis, Ebstein's anomaly, Pulmonary valve stenosis, Pulmonary valve atresia, Aortic valve atresia/stenosis, Hypoplastic left heart, Hypoplastic right heart, Coarctation of aorta, Total anomalous pulm venous return, Respiratory, Choanal atresia, Cystic adenomatous malf of lung, Digestive system, Oesophageal atresia with or without tracheo-oesophageal fistula, Duode
# ...

# %%
df.columns = df.iloc[0]

# %%
df.head()
# Out:
# 1  Country / registry      Anomaly ^  Years  Population  LB N  FD N  TOPFA N  \
# 1  Country / registry      Anomaly ^  Years  Population  LB N  FD N  TOPFA N
# 2    Styria - Austria  All Anomalies   2000       10719   337     5       33
# 3                 NaN            NaN   2001       10050   349     3       27
# 4                 NaN            NaN   2002       10511   368     7       32
# 5                 NaN            NaN   2003       10404   331     6       39
#
# 1  Total N  Total Prevalence (95% CI)    LB Prevalence (95% CI)  \
# 1  Total N  Total Prevalence (95% CI)    LB Prevalence (95% CI)
# 2      375   349.85 (315.35 - 387.09)  314.39 (281.74 - 349.80)
# 3      379   377.11 (340.12 - 417.04)  347.26 (311.80 - 385.66)
# 4      407   387.21 (350.53 - 426.70)  350.11 (315.27 - 387.75)
# 5      376   361.40 (325.81 - 399.82)  318.15 (284.81 - 354.32)
#
# 1  FD Prevalence (95% CI)  TOPFA Prevalence (95% CI)  \
# 1  FD Prevalence (95% CI)  TOPFA Prevalence (95% CI)
# ...

# %%
df.shape
# Out:
# (57269, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57269 entries, 1 to 57269
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country / registry         62 non-null     object
#  1   Anomaly ^                  3386 non-null   object
#  2   Years                      57240 non-null  object
#  3   Population                 57240 non-null  object
#  4   LB N                       57240 non-null  object
#  5   FD N                       57240 non-null  object
#  6   TOPFA N                    57240 non-null  object
#  7   Total N                    57240 non-null  object
#  8   Total Prevalence (95% CI)  57240 non-null  object
#  9   LB Prevalence (95% CI)     57240 non-null  object
#  10  FD Prevalence (95% CI)     57240 non-null  object
#  11  TOPFA Prevalence (95% CI)  57240 non-null  object
#  12  LB Proportion (95% CI)     57240 non-null  object
# ...

# %%
df.describe()
# Out:
# 1      Country / registry       Anomaly ^  Years  Population   LB N   FD N  \
# count                  62            3386  57240       57240  57240  57240
# unique                 62             110     18         507    580     50
# top     ¹² United Kingdom  Nervous system   2008           0      0      0
# freq                    1              37   3367       10647  22857  48304
#
# 1      TOPFA N Total N Total Prevalence (95% CI) LB Prevalence (95% CI)  \
# count    57240   57240                     57240                  57240
# unique     248     659                     14430                  12560
# top          0       0                         -                      -
# freq     37208   19795                     19795                  22857
#
# 1      FD Prevalence (95% CI) TOPFA Prevalence (95% CI)  \
# count                   57240                     57240
# unique                   1894                      6099
# top                         -                         -
# ...

# %%
df.head()
# Out:
# 1  Country / registry      Anomaly ^  Years  Population  LB N  FD N  TOPFA N  \
# 1  Country / registry      Anomaly ^  Years  Population  LB N  FD N  TOPFA N
# 2    Styria - Austria  All Anomalies   2000       10719   337     5       33
# 3                 NaN            NaN   2001       10050   349     3       27
# 4                 NaN            NaN   2002       10511   368     7       32
# 5                 NaN            NaN   2003       10404   331     6       39
#
# 1  Total N  Total Prevalence (95% CI)    LB Prevalence (95% CI)  \
# 1  Total N  Total Prevalence (95% CI)    LB Prevalence (95% CI)
# 2      375   349.85 (315.35 - 387.09)  314.39 (281.74 - 349.80)
# 3      379   377.11 (340.12 - 417.04)  347.26 (311.80 - 385.66)
# 4      407   387.21 (350.53 - 426.70)  350.11 (315.27 - 387.75)
# 5      376   361.40 (325.81 - 399.82)  318.15 (284.81 - 354.32)
#
# 1  FD Prevalence (95% CI)  TOPFA Prevalence (95% CI)  \
# 1  FD Prevalence (95% CI)  TOPFA Prevalence (95% CI)
# ...

# %%
df['Anomaly ^'].unique()
# Out:
# array(['Anomaly ^', 'All Anomalies', nan, 'Nervous system',
#        'Neural Tube Defects', 'Anencephalus and similar', 'Encephalocele',
#        'Spina Bifida', 'Hydrocephalus', 'Severe microcephaly',
#        'Arhinencephaly/holoprosencephaly', 'Eye',
#        'Anophthalmos/micropthalmos', 'Anophthalmos',
#        'Congenital cataract', 'Congenital glaucoma', 'Ear, face and neck',
#        'Anotia', 'Congenital heart defects', 'Severe CHD',
#        'Common arterial truncus', 'Double outlet right ventricle',
#        'Transposition of great vessels', 'Single ventricle',
#        'Ventricular septal defect (VSD)', 'Atrial septal defect (ASD)',
#        'Atrioventricular septal defect (AVSD)', 'Tetralogy of Fallot',
#        'Tricuspid atresia and stenosis', "Ebstein's anomaly",
#        'Pulmonary valve stenosis', 'Pulmonary valve atresia',
#        'Aortic valve atresia/stenosis', 'Mitral valve anomalies',
#        'Hypoplastic left heart', 'Hypoplastic right heart',
# ...

# %%
df[df['Anomaly ^']=='Milan Area - Italy (2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011)']
# Out:
# 1     Country / registry                                          Anomaly ^  \
# 57258            ⁸ Italy  Milan Area - Italy (2000, 2001, 2002, 2003, 20...
#
# 1     Years Population LB N FD N TOPFA N Total N Total Prevalence (95% CI)  \
# 57258   NaN        NaN  NaN  NaN     NaN     NaN                       NaN
#
# 1     LB Prevalence (95% CI) FD Prevalence (95% CI) TOPFA Prevalence (95% CI)  \
# 57258                    NaN                    NaN                       NaN
#
# 1     LB Proportion (95% CI) FD Proportion (95% CI) TOPFA Proportion (95% CI)
# 57258                    NaN                    NaN                       NaN

# %%
df['Country / registry'].unique()
# Out:
# array(['Country / registry', 'Styria - Austria', nan, 'Antwerp - Belgium',
#        'Hainaut - Belgium', 'Pleven - Bulgaria ¹', 'Zagreb - Croatia',
#        'Odense - Denmark', 'Paris - France', 'Auvergne - France ²',
#        'Isle de la Reunion - France ⁵', 'French West Indies - France ⁴',
#        'Brittany - France ³', 'Saxony-Anhalt - Germany',
#        'Mainz - Germany ⁶', 'Dublin - Ireland ⁷',
#        'Cork and Kerry - Ireland', 'SE Ireland - Ireland',
#        'Milan Area - Italy ⁸', 'Emilia Romagna - Italy',
#        'Tuscany - Italy', 'Malta - Malta', 'N Netherlands - NL',
#        'Norway - Norway', 'Wielkopolska - Poland',
#        'S Portugal - Portugal', 'Basque Country - Spain',
#        'Valencian Region - Spain ¹⁰', 'Navarre - Spain ⁹',
#        'Vaud - Switzerland', 'Ukraine - Ukraine ¹¹',
#        'Wales - United Kingdom', 'Thames Valley - United Kingdom',
#        'Wessex - United Kingdom',
#        'East Midlands & South Yorkshire - United Kingdom',
# ...

# %%
df.tail(40)
# Out:
# 1                                     Country / registry  \
# 57230                                                NaN
# 57231                                                NaN
# 57232                                                NaN
# 57233                                                NaN
# 57234                                                NaN
# 57235                                                NaN
# 57236                                                NaN
# 57237                                                NaN
# 57238                                                NaN
# 57239                                                NaN
# 57240                                                NaN
# 57241                                                NaN
# 57242                                   LB = Live Births
# 57243  FD = Fetal Deaths / Still Births from 20 weeks...
# 57244  TOPFA = Termination of pregnancy for fetal ano...
# ...

# %%
df = df.iloc[:57240]

# %%
df['Country / registry'].value_counts()
# Out:
# Wessex - United Kingdom                             1
# SE Ireland - Ireland                                1
# Country / registry                                  1
# Norway - Norway                                     1
# S Portugal - Portugal                               1
# Vaud - Switzerland                                  1
# Yorkshire and Humber - United Kingdom ¹⁴            1
# Antwerp - Belgium                                   1
# Hainaut - Belgium                                   1
# Tuscany - Italy                                     1
# West Midlands - United Kingdom ¹³                   1
# Navarre - Spain ⁹                                   1
# French West Indies - France ⁴                       1
# Thames Valley - United Kingdom                      1
# Wales - United Kingdom                              1
# Paris - France                                      1
# Auvergne - France ²                                 1
# ...

# %%
[lambda x: x.apply('Styria - Austria') if x == 'NaN' in df['Country / registry'] else 'Styria - Austria']
# Out:
# [<function __main__.<lambda>(x)>]

# %%
df = df[1:]

# %%
df.head(30)
# Out:
# 1  Country / registry       Anomaly ^ Years Population LB N FD N TOPFA N  \
# 2    Styria - Austria   All Anomalies  2000      10719  337    5      33
# 3                 NaN             NaN  2001      10050  349    3      27
# 4                 NaN             NaN  2002      10511  368    7      32
# 5                 NaN             NaN  2003      10404  331    6      39
# 6                 NaN             NaN  2004      10510  392    5      36
# 7                 NaN             NaN  2005      10473  357    3      41
# 8                 NaN             NaN  2006      10327  288    2      39
# 9                 NaN             NaN  2007      10209  231    4      47
# 10                NaN             NaN  2008      10281  215    3      41
# 11                NaN             NaN  2009      10235  240   12      38
# 12                NaN             NaN  2010      10442  253    2      40
# 13                NaN             NaN  2011      10226  226    2      38
# ...

# %%
df['Country / registry'] = df['Country / registry'].astype(str)

# %%
[x for x in df['Country / registry'] if x != 'nan']
#order in which the countries are in
# Out:
# ['Styria - Austria',
#  'Antwerp - Belgium',
#  'Hainaut - Belgium',
#  'Pleven - Bulgaria ¹',
#  'Zagreb - Croatia',
#  'Odense - Denmark',
#  'Paris - France',
#  'Auvergne - France ²',
#  'Isle de la Reunion - France ⁵',
#  'French West Indies - France ⁴',
#  'Brittany - France ³',
#  'Saxony-Anhalt - Germany',
#  'Mainz - Germany ⁶',
#  'Dublin - Ireland ⁷',
#  'Cork and Kerry - Ireland',
#  'SE Ireland - Ireland',
#  'Milan Area - Italy ⁸',
#  'Emilia Romagna - Italy',
#  'Tuscany - Italy',
#  'Malta - Malta',
#  'N Netherlands - NL',
#  'Norway - Norway',
#  'Wielkopolska - Poland',
#  'S Portugal - Portugal',
#  'Basque Country - Spain',
#  'Valencian Region - Spain ¹⁰',
#  'Navarre - Spain ⁹',
#  'Vaud - Switzerland',
#  'Ukraine - Ukraine ¹¹',
#  'Wales - United Kingdom',
#  'Thames Valley - United Kingdom',
#  'Wessex - United Kingdom',
#  'East Midlands & South Yorkshire - United Kingdom',
#  'Northern England - United Kingdom',
# ...

# %%
df[df['Country / registry'] == 'Styria - Austria']
# Out:
# 1 Country / registry      Anomaly ^ Years Population LB N FD N TOPFA N  \
# 2   Styria - Austria  All Anomalies  2000      10719  337    5      33
#
# 1 Total N Total Prevalence (95% CI)    LB Prevalence (95% CI)  \
# 2     375  349.85 (315.35 - 387.09)  314.39 (281.74 - 349.80)
#
# 1 FD Prevalence (95% CI) TOPFA Prevalence (95% CI)    LB Proportion (95% CI)  \
# 2    4.66 (1.48 - 10.92)     30.79 (21.19 - 43.23)  89.87% (86.40% - 92.53%)
#
# 1 FD Proportion (95% CI) TOPFA Proportion (95% CI)
# 2  1.33% (0.57% - 3.08%)    8.80% (6.33% - 12.10%)

# %%
df[df['Country / registry'] == 'Antwerp - Belgium']
# Out:
# 1    Country / registry      Anomaly ^ Years Population LB N FD N TOPFA N  \
# 1549  Antwerp - Belgium  All Anomalies  2000      18159  435    7      53
#
# 1    Total N Total Prevalence (95% CI)    LB Prevalence (95% CI)  \
# 1549     495  272.59 (249.12 - 297.69)  239.55 (217.58 - 263.14)
#
# 1    FD Prevalence (95% CI) TOPFA Prevalence (95% CI)  \
# 1549     3.85 (1.53 - 7.96)     29.19 (21.87 - 38.17)
#
# 1       LB Proportion (95% CI) FD Proportion (95% CI)  \
# 1549  87.88% (84.71% - 90.47%)  1.41% (0.69% - 2.89%)
#
# 1    TOPFA Proportion (95% CI)
# 1549   10.71% (8.28% - 13.74%)

# %%
df['Country / registry'].iloc[1:1548] = df['Country / registry'].iloc[1:1548].replace('nan','Styria - Austria')

# %%
df['Country / registry']
# Out:
# 2        Styria - Austria
# 3        Styria - Austria
# 4        Styria - Austria
# 5        Styria - Austria
# 6        Styria - Austria
#                ...
# 57236                 nan
# 57237                 nan
# 57238                 nan
# 57239                 nan
# 57240                 nan
# Name: Country / registry, Length: 57239, dtype: object

# %%
df[df['Country / registry'] == 'Hainaut - Belgium']
# Out:
# 1    Country / registry      Anomaly ^ Years Population LB N FD N TOPFA N  \
# 3096  Hainaut - Belgium  All Anomalies  2000      12823  273    2      44
#
# 1    Total N Total Prevalence (95% CI)    LB Prevalence (95% CI)  \
# 3096     319  248.77 (222.24 - 277.61)  212.90 (188.41 - 239.70)
#
# 1    FD Prevalence (95% CI) TOPFA Prevalence (95% CI)  \
# 3096     1.56 (0.15 - 5.69)     34.31 (24.94 - 46.06)
#
# 1       LB Proportion (95% CI) FD Proportion (95% CI)  \
# 3096  85.58% (81.30% - 89.01%)  0.63% (0.17% - 2.26%)
#
# 1    TOPFA Proportion (95% CI)
# 3096  13.79% (10.44% - 18.01%)

# %%
df['Country / registry'].iloc[1548:1548] = df['Country / registry'].iloc[1:1548].replace('nan','Styria - Austria')
