# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import re
sns.set(font_scale=1.5)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
df = pd.read_csv('/Users/dayosangowawa/Desktop/Side Projects 2022/EU congenital anomalies data analysis/final_df.csv')

# %%
df.describe()
# Out:
#               years    population   live_births  still_births  \
# count  34382.000000  34382.000000  34382.000000  34382.000000
# mean    2008.531034  24871.431447     23.097784      0.631173
# std        4.803047  16594.349053     80.541063      2.318242
# min     2000.000000   2223.000000      1.000000      0.000000
# 25%     2005.000000  10723.000000      2.000000      0.000000
# 50%     2009.000000  21316.000000      5.000000      0.000000
# 75%     2013.000000  33026.000000     15.000000      0.000000
# max     2016.000000  76439.000000   2487.000000     78.000000
#
#        termination_of_pregnancy_for_fetal_anomaly_following_prenatal_diagnosis  \
# count                                       34382.000000
# mean                                            5.603135
# std                                            20.352230
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                           422.000000
#
#        total_no_of_cases  lb_proportion_  still_birth_proportion_  \
# count       34382.000000    34382.000000             34382.000000
# mean           29.332092       80.644124                 2.494606
# std            97.639859       25.116032                 7.308783
# min             1.000000        1.470000                 0.000000
# 25%             3.000000       66.670000                 0.000000
# 50%             7.000000       92.860000                 0.000000
# 75%            20.000000      100.000000                 0.000000
# max          2685.000000      100.000000                83.330000
#
#        topfa_proportion_           gdp
# count       34382.000000  3.438200e+04
# mean           16.861287  1.398767e+12
# std            23.891891  1.127068e+12
# min             0.000000  4.069516e+09
# 25%             0.000000  2.872265e+11
# 50%             1.070000  1.270712e+12
# 75%            27.500000  2.491110e+12
# max            98.530000  3.883920e+12
